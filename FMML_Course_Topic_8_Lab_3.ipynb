# %% [markdown]
# <a href="https://colab.research.google.com/github/Durgaprasadkudupudi/FMML_PROJECT_AND_LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 07:17:04--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   105MB/s    in 0.7s
#
# 2024-03-25 07:17:13 (105 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11005   1310.2451v2  Regularization is used to find a solution that...  stat
# 22990  1712.09988v2  There has been growing interest in how economi...  stat
# 29624  1709.09843v1  Exploiting multiple modalities for semantic sc...    cs
# 23047  1802.07481v2  Convex sparsity-inducing regularizations are u...  stat
# 2697   1706.08001v1  In this article, we extend the conventional fr...    cs
# ...             ...                                                ...   ...
# 11707  1610.03483v4  Generative adversarial networks (GANs) provide...  stat
# 35080  1706.07296v1  Different subsystems of organisms adapt over m...    cs
# 21882   1405.0530v1  We propose a novel non-parametric adaptive ano...  stat
# 24092  1612.05363v2  Face attributes are interesting due to their d...    cs
# 21702   0907.4643v2  We discuss here the mean-field theory for a ce...  stat
#
#                                                    title  year  \
# 11005       M-Power Regularized Least Squares Regression  2013
# 22990  Orthogonal Machine Learning for Demand Estimat...  2017
# 29624   Soft Correspondences in Multimodal Scene Parsing  2017
# 23047        Dual Extrapolation for Faster Lasso Solvers  2018
# 2697   Temporal-related Convolutional-Restricted-Bolt...  2017
# ...                                                  ...   ...
# 11707             Learning in Implicit Generative Models  2016
# 35080  A Minimal Developmental Model Can Increase Evo...  2017
# 21882           A Rank-SVM Approach to Anomaly Detection  2014
# 24092  Learning Residual Images for Face Attribute Ma...  2016
# 21702                 Mean-Field Theory of Meta-Learning  2009
#
#                                                 keywords
# 11005  [regularization, sufficiently, effective, desi...
# 22990  [economists, prediction, accelerate, selection...
# 29624  [exploiting, modalities, singlemodality, multi...
# 23047  [regularizations, ubiquitous, dimension, diffe...
# 2697   [conventional, framework, convolutional, restr...
# ...                                                  ...
# 11707  [generative, adversarial, algorithmic, framewo...
# 35080  [different, subsystems, organisms, morphologic...
# 21882  [parametric, detection, algorithm, dimensional...
# 24092  [attributes, interesting, description, researc...
# 21702  [combining, individual, procedures, determine,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11005    [regularization, sufficiently, effective, desi...
# 22990    [economists, prediction, accelerate, selection...
# 29624    [exploiting, modalities, singlemodality, multi...
# 23047    [regularizations, ubiquitous, dimension, diffe...
# 2697     [conventional, framework, convolutional, restr...
#                                ...
# 12571    [principal, components, dimension, reduction, ...
# 21861    [selection, clustering, estimation, unsupervis...
# 17206    [communication, consequence, different, societ...
# 38279    [addresses, sentiment, classifying, according,...
# 6229     [classifier, classification, minimizes, classi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8875 words.
# Out of those 4570 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c3cd240a-072c-428d-a213-fdf4c7722e68" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3cd240a-072c-428d-a213-fdf4c7722e68")) {                    Plotly.newPlot(                        "c3cd240a-072c-428d-a213-fdf4c7722e68",                        [{"x":["stability","associated","efficient","advantage","effective","reproducing","efficiency","regression","quadratic","particular","algorithm","designing","understood","algorithms","regularized","suggestion","minimization","sufficiently","convergence","computational","classical","influence","regularization","theoretical","efficiently","significantly","complexity","prediction","inference","exogenous","asymptotic","desirable","selection","retaining","practitioners","estimator","treatments","partially","parameters","framework","dimensionality","economists","coefficients","accelerate","alternative","equivalent","sequentially","dimensional","estimation","properties","estimating","orthogonal","estimators","treatment","information","corresponding","identical","explicitly","exploiting","introducing","formulating","satisfactory","improvements","correspondences","available","performed","inconsistencies","inconsistent","simultaneous","misalignment","geometric","outperforms","modalities","potential","highlight","functions","containing","multimodal","techniques","technique","discarding","dimension","aggressive","prioritizing","optimization","optimality","iterative","criterion","performance","regularizations","extrapolation","approaches","differentiability","irrelevant","ubiquitous","screening","construction","procedure","convolutional","developed","relations","reinforcement","conventional","multiplicative","restricted","constructing","relational","boltzmann","independent","attractive","analyzing","principal","component","connections","objective","demonstrate","optimized","manifolds","reduction","technology","highlighted","structure","interpretations","suboptimality","correlation","straightforward","covariance","dynamical","disparate","literature","relationships","multidimensional","solutions","projection","numerical","motivations","canonical","generalizations","autocorrelation","correlations","sufficient","eigenvector","typically","shortcomings","discussed","discriminant","probability","eligibility","simulations","assumption","difference","approximation","prioritized","dramatically","challenges","recognition","appropriate","supervised","extraction","challenge","architectures","hierarchical","introduce","capabilities","depending","maintaining","injection","baselines","unsupervised","analogous","unconstrained","operation","evaluation","introduced","individually","partition","biologically","specialised","augmentation","individual","processing","environments","constituent","providing","percentages","periodically","outperform","knowledge","generalising","ensembles","established","sophisticated","architecture","availability","differing","conditions","threshold","comparisons","adversarial","classifier"],"y":[31,113,419,75,262,11,140,108,24,276,793,47,20,602,40,2,76,21,134,268,103,56,78,155,149,272,246,232,219,4,11,25,161,12,13,27,5,56,237,552,54,0,35,19,100,57,14,174,220,218,73,29,14,25,717,137,20,57,74,52,11,19,101,28,313,121,6,16,28,3,88,257,40,147,28,222,60,44,362,218,3,74,3,2,291,20,68,48,869,0,2,407,0,17,18,13,66,133,387,194,97,104,118,13,44,37,39,9,102,13,59,44,107,45,168,559,65,19,105,52,9,353,15,5,73,18,24,18,3,107,76,16,148,42,90,4,21,10,1,24,63,4,94,13,65,17,182,4,33,58,59,114,6,23,127,388,92,195,131,175,115,101,331,48,45,39,5,58,160,8,22,39,252,135,21,26,13,1,26,124,277,90,13,101,1,1,106,362,2,17,45,25,239,17,7,135,50,30,111,131],"type":"bar"},{"x":["stability","associated","effici ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4570,), (4570, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Schema</span> <span style=''>Editor</span> <span style=''>of</span> <span style=''>OpenIoT</span> <span style=''>for</span> <span style=''>Semantic</span> <span style=''>Sensor</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.92);'>Ontologies</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.37931034482758624);'>conceptual</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>abstractions</span> <span style=''>over</span> <span style=''>data</span> <span style=''>in</span> <span style=''>domains</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Internet</span> <span style=''>of</span> <span style=''>Things</span> <span style=''>in</span> <span style=''>a</span> <span style=''>way</span> <span style=''>that</span> <span style=''>sensor</span> <span style=''>data</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>harvested</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>interpreted</span> <span style=''>by</span> <span style=''>people</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>The</span> <span style=''>Semantic</span> <span style=''>Sensor</span> <span style=''>Network</span> <span style=''>(SSN)</span> <span style=''>ontology</span> <span style=''>is</span> <span style=''>the</span> <span style=''>de</span> <span style=''>facto</span> <span style=''>standard</span> <span style=''>for</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.39162112932604737);'>representation</span> <span style=''>of</span> <span style=''>sensor</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>observations</span> <span style=''>and</span> <span style=''>metadata</span> <span style=''>and</span> <span style=''>it</span> <span style=''>is</span> <span style=''>used</span> <span style=''>at</span> <span style=''>the</span> <span style=''>core</span> <span style=''>of</span> <span style=''>the</span> <span style=''>open</span> <span style=''>source</span> <span style=''>platform</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Internet</span> <span style=''>of</span> <span style=''>Things</span> <span style=''>OpenIoT</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>Schema</span> <span style=''>Editor</span> <span style=''>that</span> <span style=''>provides</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitive</span> <span style=''>web</span> <span style='background-color:rgba(0, 255, 0, 0.5454545454545454);'>interface</span> <span style=''>for</span> <span style=''>defining</span> <span style=''>new</span> <span style=''>types</span> <span style=''>of</span> <span style=''>sensors</span> <span style=''>and</span> <span style=''>concrete</span> <span style='background-color:rgba(0, 255, 0, 0.35820895522388063);'>instances</span> <span style=''>of</span> <span style=''>them</span> <span style=''>using</span> <span style=''>the</span> <span style=''>SSN</span> <span style=''>ontology</span> <span style=''>as</span> <span style=''>the</span> <span style=''>core</span> <span style=''>model</span> <span style=''>This</span> <span style=''>editor</span> <span style=''>is</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.4651162790697675);'>integrated</span> <span style=''>with</span> <span style=''>the</span> <span style=''>OpenIoT</span> <span style=''>platform</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.352112676056338);'>generating</span> <span style=''>v ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Modelling</span> <span style=''>of</span> <span style=''>Paired</span> <span style=''>Symbols</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>scalable</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occurrence</span> <span style=''>of</span> <span style=''>pairs</span> <span style=''>of</span> <span style=''>symbols</span> <span style=''>(ij)</span> <span style=''>drawn</span> <span style=''>from</span> <span style=''>a</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>vocabulary</span> <span style=''>Observed</span> <span style=''>pairs</span> <span style=''>are</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>popularity</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>process</span> <span style=''>followed</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>censoring</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preference</span> <span style=''>function</span> <span style=''>By</span> <span style=''>basing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>on</span> <span style=''>the</span> <span style=''>well</span> <span style=''>founded</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>bounding</span> <span style=''>and</span> <span style=''>using</span> <span style=''>new</span> <span style=''>site</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>bounds</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>a</span> <span style=''>scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>for</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>State</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>results</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>on</span> <span style=''>real</span> <span style=''>world</span> <span style=''>movie</span> <span style=''>viewing</span> <span style=''>data</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>Modeling</span> <span style=''>Profiles</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>Values</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>an</span> <span style=''>observed</span> <span style=''>sample</span> <span style=''>of</span> <span style=''>data</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.4615384615384616);'>likelihood</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>ob</span> <span style=''>served</span> <span style=''>values</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.32680320569902044);'>different</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>high</span> <span style=''>profile</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>profile</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>symbols</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appearing</span> <span style=''>any</span> <span style=''>given</span> <span style=''>number</span> <span style=''>of</span> <span style=''>times</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determine</span> <span style=''>the</span> <span style=''>high</span> <span style=''>profile</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>several</span> <span style=''>data</span> <span style=''>samples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>some</span> <span style=''>of</span> <span style=''>its</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>when</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>distinct</span> <span style=''>symbols</span> <span style=''>observed</span> <span style=''>is</span> <span style=''>small</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>data</span> <span style=''>size</span> <span style=''>the</span> <span style=''>high</span> <span style=''>profile</span> <span style=''>and</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.4615384615384616);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>are</span> <span style=''>roughly</span> <span style=''>the</span> <span style=''>same</span> <span style=''>but</span> <span style=''>when</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>symbols</span> <span style=''>is</span> <span style=''>large</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>differ</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Towards</span> <span style=''>life</span> <span style=''>cycle</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>of</span> <span style=''>malaria</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parasites</span> <span style=''>using</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Riemannian</span> <span style=''>geometry</span> <br/><br/><span style=''>Malaria</span> <span style=''>is</span> <span style=''>a</span> <span style=''>serious</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>infectious</span> <span style=''>disease</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responsible</span> <span style=''>for</span> <span style=''>over</span> <span style=''>half</span> <span style=''>million</span> <span style=''>deaths</span> <span style=''>yearly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>worldwide</span> <span style=''>The</span> <span style=''>major</span> <span style=''>cause</span> <span style=''>of</span> <span style=''>these</span> <span style=''>mortalities</span> <span style=''>is</span> <span style=''>late</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inaccurate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diagnosis</span> <span style=''>Manual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>microscopy</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>currently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>as</span> <span style=''>the</span> <span style=''>dominant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diagnostic</span> <span style=''>method</span> <span style=''>for</span> <span style=''>malaria</span> <span style=''>However</span> <span style=''>it</span> <span style=''>is</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consuming</span> <span style=''>and</span> <span style=''>prone</span> <span style=''>to</span> <span style=''>human</span> <span style=''>errors</span> <span style=''>The</span> <span style=''>aim</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>automate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diagnosis</span> <span style=''>process</span> <span style=''>and</span> <span style=''>minimize</span> <span style=''>the</span> <span style=''>human</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intervention</span> <span style=''>We</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>the</span> <span style=''>hardware</span> <span style=''>and</span> <span style=''>software</span> <span style=''>for</span> <span style=''>a</span> <span style=''>cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>malaria</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diagnostic</span> <span style=''>system</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>describes</span> <span style=''>the</span> <span style=''>manufactured</span> <span style=''>hardware</span> <span style=''>and</span> <span style=''>also</span> <span style=''>proposes</span> <span style=''>novel</span> <span style=''>software</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>parasite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>and</span> <span style=''>life</span> <span style=''>stage</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09006433166547534)
# 	architecture (0.0854181558255897)
# 	representation (0.13652609006433167)
# 	segmentation (0.07433881343817011)
# 	knowledge (0.12937812723373837)
# 	information (0.2562544674767691)
# 	detection (0.12866333095067906)
# 	different (0.2662616154395997)
# 	convolutional (0.13831308077197998)
# 	recognition (0.13867047891350964)
#
# Some Statistics words are:
# 	stochastic (0.12437562437562437)
# 	estimation (0.16983016983016982)
# 	variables (0.13736263736263737)
# 	algorithm (0.3821178821178821)
# 	theoretical (0.15734265734265734)
# 	distribution (0.18181818181818182)
# 	statistical (0.16483516483516483)
# 	inference (0.1973026973026973)
# 	dimensional (0.1963036963036963)
# 	regression (0.18181818181818182)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0926d8f3-98a2-4f3b-b571-cb3435f9ccf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0926d8f3-98a2-4f3b-b571-cb3435f9ccf9")) {                    Plotly.newPlot(                        "0926d8f3-98a2-4f3b-b571-cb3435f9ccf9",                        [{"x":["stability","associated","efficient","advantage","effective","reproducing","efficiency","regression","quadratic","particular","algorithm","designing","understood","algorithms","regularized","suggestion","minimization","sufficiently","convergence","computational","classical","influence","regularization","theoretical","efficiently","significantly","complexity","prediction","inference","exogenous","asymptotic","desirable","selection","retaining","practitioners","estimator","treatments","partially","parameters","framework","dimensionality","economists","coefficients","accelerate","alternative","equivalent","sequentially","dimensional","estimation","properties","estimating","orthogonal","estimators","treatment","information","corresponding","identical","explicitly","exploiting","introducing","formulating","satisfactory","improvements","correspondences","available","performed","inconsistencies","inconsistent","simultaneous","misalignment","geometric","outperforms","modalities","potential","highlight","functions","containing","multimodal","techniques","technique","discarding","dimension","aggressive","prioritizing","optimization","optimality","iterative","criterion","performance","regularizations","extrapolation","approaches","differentiability","irrelevant","ubiquitous","screening","construction","procedure","convolutional","developed","relations","reinforcement","conventional","multiplicative","restricted","constructing","relational","boltzmann","independent","attractive","analyzing","principal","component","connections","objective","demonstrate","optimized","manifolds","reduction","technology","highlighted","structure","interpretations","suboptimality","correlation","straightforward","covariance","dynamical","disparate","literature","relationships","multidimensional","solutions","projection","numerical","motivations","canonical","generalizations","autocorrelation","correlations","sufficient","eigenvector","typically","shortcomings","discussed","discriminant","probability","eligibility","simulations","assumption","difference","approximation","prioritized","dramatically","challenges","recognition","appropriate","supervised","extraction","challenge","architectures","hierarchical","introduce","capabilities","depending","maintaining","injection","baselines","unsupervised","analogous","unconstrained","operation","evaluation","introduced","individually","partition","biologically","specialised","augmentation","individual","processing","environments","constituent","providing","percentages","periodically","outperform","knowledge","generalising","ensembles","established","sophisticated","architecture","availability","differing","conditions","threshold","comparisons","adversarial","classifier","characterize","applications","interactive","comparison","instances","interactively","obtaining","improving","considering","maximizes","important","dependency","penalized","attention","potentially","relevancy","redundancy","characteristic","detecting","interaction","sometimes","rademacher","statistical","classification","described","previously","dimensions","complements","dictionary","combination","dictionaries","representation","coefficient","magnitude","localized","distribution","smoothness","separation","generalization","including","orthogonality","denoising","generated","perspective","questions","requirements","constraints","represented","probabilistic","representing","generating","underlyi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	economists
# 	regularizations
# 	differentiability
# 	coincides
# 	robustify
# 	epidemiology
# 	underestimates
# 	certifiable
# 	synchronously
# 	confounders
# 	emphsparse
# 	markovian
# 	envelopes
# 	supermarket
# 	compounded
# 	reparametrization
# 	collinearity
# 	condensed
# 	occasionally
# 	nesterovs
# Some words which never appear in Statistics papers:
# 	inconsistencies
# 	misalignment
# 	eligibility
# 	trustable
# 	underexplored
# 	syllables
# 	phonological
# 	intonational
# 	unlearned
# 	memorability
# 	memorable
# 	programmer
# 	entailment
# 	acoustical
# 	endangered
# 	terminals
# 	touchscreen
# 	authentication
# 	fragments
# 	intractability

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0721966205837174e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
